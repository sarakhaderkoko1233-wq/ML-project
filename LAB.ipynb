# %% [markdown]
# <a href="https://colab.research.google.com/github/sarakhaderkoko1233-wq/ML-project/blob/m/LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder , LabelEncoder
df=pd.read_csv('/content/titanic_with_nan.csv')
cf = ["Sex","Embarked","Pclass"]
ct = ColumnTransformer(transformers=['encoder',OneHotEncoder,cf],remainder='passthrough')
ct.fit_transform(df)
x=pd.DataFrame(cf)
print(x.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3964142915.py in <cell line: 0>()
#       7 cf = ["Sex","Embarked","Pclass"]
#       8 ct = ColumnTransformer(transformers=['encoder',OneHotEncoder,cf],remainder='passthrough')
# ----> 9 ct.fit_transform(df)
#      10 x=pd.DataFrame(cf)
#      11 print(x.head())
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# ...
